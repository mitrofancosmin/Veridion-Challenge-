# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm

# Load the dataset
parquet_file =  r'B:\Python\Veridion Project\Project 4\veridion_product_deduplication_challenge.snappy.parquet'
df = pd.read_parquet(parquet_file, engine="auto")
print (df)
# Out:
#                                                   unspsc  \
# 0      Sewing and stitchery and weaving equipment and...
# 1                 Electric alternating current AC motors
# 2                     Vehicle trim and exterior covering
# 3                                        Pipe connectors
# 4                                                  Doors
# ...                                                  ...
# 21941                                              Other
# 21942                     Processed and synthetic rubber
# 21943                            Fresh cut rose bouquets
# 21944  Vision correction or cosmetic eyewear and rela...
# 21945       Chocolate and sugars and sweetening products
#
#                          root_domain  \
# 0                  studio-atcoat.com
# 1                     worm-gears.net
# 2               customcarcoverco.com
# 3                    plumbmaster.com
# 4                           sogno.in
# ...                              ...
# 21941                   dsbridal.com
# 21942               50735-in.all.biz
# 21943             lilyofthevalley.uk
# 21944  getcontactlensesonline.com.au
# 21945           malagoschocolate.com
#
#                                                 page_url  \
# 0          https://studio-atcoat.com/1372696759/?idx=510
# 1              https://worm-gears.net/tag/worm-gear-box/
# 2      https://customcarcoverco.com/collections/vendo...
# 3      https://www.plumbmaster.com/search?q=wolverine...
# 4      http://www.sogno.in/product-detail-CST-HGD-331...
# ...                                                  ...
# 21941  https://www.dsbridal.com/index.php/sale/veils....
# 21942               https://50735-in.all.biz/group-goods
# 21943  https://www.lilyofthevalley.uk/product/luxurio...
# 21944  https://getcontactlensesonline.com.au/brand/al...
# 21945  https://malagoschocolate.com/collections/ready...
#
#                                        product_title  \
# 0                        Glimakra Warping Board (8m)
# 1                            NMRV Worm Gearbox Motor
# 2                           Nissan R33 GTR Car Cover
# 3                                  Flexible Fittings
# 4                   CST-HGD-33103 Hinged Closet Door
# ...                                              ...
# 21941                              15/16 Accessories
# 21942                General Mechanical Rubber Goods
# 21943                          Luxurious Rose Garden
# 21944  Dailies AquaComfort Plus Multifocal (30 Pack)
# 21945   Signature Dark Collection 85% Dark Chocolate
#
#                                          product_summary  \
# 0      The Glimakra Warping Board is designed for use...
# 1      The NMRV Worm Gearbox Motor is a high-efficien...
# 2      A custom car cover designed for the Nissan R33...
# 3      Flexible fittings for plumbing applications, a...
# 4      The CST-HGD-33103 Hinged Closet Door is a meti...
# ...                                                  ...
# 21941  Accessories designed for Sweet 15/16, availabl...
# 21942  A category of rubber goods designed for genera...
# 21943  The Luxurious Rose Garden is a stunning floral...
# 21944  A pack of 30 Dailies AquaComfort Plus Multifoc...
# 21945  A Signature Dark Collection product from Malag...
#
#                     product_name product_identifier  \
# 0                  Warping Board                 []
# 1             Worm Gearbox Motor                 []
# 2                      Car Cover                 []
# 3              Flexible Fittings                 []
# 4             Hinged Closet Door                 []
# ...                          ...                ...
# 21941                Accessories                 []
# 21942               Rubber Goods                 []
# 21943         Floral Arrangement                 []
# 21944  Multifocal Contact Lenses                 []
# 21945             Dark Chocolate                 []
#
#                             brand              intended_industries  \
# 0                            None                        [Textile]
# 1                            None                     [Industrial]
# 2                            None                     [Automotive]
# 3                            None                       [Plumbing]
# 4                             CST  [Home Appliances, Construction]
# ...                           ...                              ...
# 21941                        None                         [Retail]
# 21942                        None                  [Manufacturing]
# 21943  Lily Of The Valley Florist                  [Retail, Gifts]
# 21944                     Dailies                     [Healthcare]
# 21945           Malagos Chocolate                [Food & Beverage]
#
#                                  applicability  ...     form  \
# 0                       [use with floor looms]  ...       []
# 1                    [industrial applications]  ...       []
# 2      [protecting vehicles from the elements]  ...       []
# 3                     [plumbing installations]  ...       []
# 4                             [Closet Storage]  ...       []
# ...                                        ...  ...      ...
# 21941            [accessories for Sweet 15/16]  ...       []
# 21942                                       []  ...       []
# 21943           [gifting, decorative purposes]  ...       []
# 21944                      [vision correction]  ...       []
# 21945                                       []  ...  [Solid]
#
#                                                     size  \
# 0      [{'dimension': 'Length', 'qualitative': False,...
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 21941  [{'dimension': 'Diameter', 'qualitative': Fals...
# 21942                                                 []
# 21943  [{'dimension': 'Width', 'qualitative': False, ...
# 21944                                                 []
# 21945                                                 []
#
#                                                    color purity  \
# 0                                                     []     []
# 1      [{'original': 'Blue', 'simple': 'Blue'}, {'ori...     []
# 2                                                     []     []
# 3                                                     []     []
# 4                                                     []     []
# ...                                                  ...    ...
# 21941                                                 []     []
# 21942                                                 []     []
# 21943                                                 []     []
# 21944                                                 []     []
# 21945                                                 []     []
#
#       energy_efficiency pressure_rating  \
# 0                  None              []
# 1                  None              []
# 2                  None              []
# 3                  None              []
# 4                  None              []
# ...                 ...             ...
# 21941              None              []
# 21942              None              []
# 21943              None              []
# 21944              None              []
# 21945              None              []
#
#                                             power_rating  \
# 0                                                     []
# 1      [{'qualitative': False, 'type': 'min', 'unit':...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 21941                                                 []
# 21942                                                 []
# 21943                                                 []
# 21944                                                 []
# 21945                                                 []
#
#        quality_standards_and_certifications  \
# 0                                        []
# 1                                        []
# 2                                        []
# 3                                        []
# 4                                        []
# ...                                     ...
# 21941                                    []
# 21942                                    []
# 21943                                    []
# 21944                                    []
# 21945                                    []
#
#                                   miscellaneous_features  \
# 0                                                     []
# 1      [Omnibearing installation, High radiation effi...
# 2      [Personalization with custom brand logos, grap...
# 3      [allows for movement, flexibility in installat...
# 4      [Italian craftsmanship, German engineering, Sm...
# ...                                                  ...
# 21941                      [part of the sale collection]
# 21942                                                 []
# 21943  [Product images available in various resolutions]
# 21944                                                 []
# 21945                                                 []
#
#                                              description
# 0      The "Warping Board" is designed for use with f...
# 1      The "Worm Gearbox Motor" is a high-efficiency ...
# 2      The "Car Cover" is a custom-designed cover tai...
# 3      "Flexible Fittings" are designed for plumbing ...
# 4      The "Hinged Closet Door" is a storage solution...
# ...                                                  ...
# 21941  "Accessories" are designed for use with Sweet ...
# 21942  "Rubber Goods" are designed for general mechan...
# 21943  "The 'Floral Arrangement' offered by Lily Of T...
# 21944  "Multifocal Contact Lenses" are designed for d...
# 21945  "Dark Chocolate" from Malagos Chocolate is a r...
#
# [21946 rows x 31 columns]

# %%
empty_products = df[df['description'].isnull() | df['description'].str.strip().eq('') | df['product_summary'].isnull() | df['product_summary'].str.strip().eq('')]

# Display products with empty descriptions or summaries
# print(empty_products[['unspsc', 'product_identifier', 'description', 'product_summary']])
df_clean = df[~df['product_identifier'].isin(empty_products['product_identifier'])]
grouped = df_clean.groupby('unspsc')

print(grouped)

# %%
#check similarity within each group and remove duplicates
def remove_duplicates_within_group(group):
    # Concatenate 'description' and 'product_summary' to create a single text column
    group['combined_text'] = group['description'].fillna('') + " " + group['product_summary'].fillna('')
    group = group[group['combined_text'].str.strip() != '']
    
    if group.empty:
        return group  # Return empty group as-is (no products to process)
    vectorizer = TfidfVectorizer(stop_words='english')
    tfidf_matrix = vectorizer.fit_transform(group['combined_text'])
    cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
    to_keep = set()
    for i in range(len(group)):
        if i not in to_keep:
            to_keep.add(i) 
            for j in range(i + 1, len(group)):
                if cosine_sim[i, j] > 0.8:
                    to_keep.add(j)
    return group.iloc[list(to_keep)]

# %%
cleaned_df = pd.concat([remove_duplicates_within_group(group) for _, group in tqdm(grouped, desc="Removing duplicates")])
print("Cleaned DataFrame with duplicates removed and empty descriptions/summaries eliminated:")
print(cleaned_df[['unspsc', 'product_identifier', 'description', 'product_summary']])
# Out:
# Removing duplicates: 100%|████████████████████████████████████████████████████████| 1492/1492 [00:10<00:00, 147.12it/s]
# Cleaned DataFrame with duplicates removed and empty descriptions/summaries eliminated:
#                 unspsc product_identifier  \
# 741    Abrasive wheels                 []
# 6649   Abrasive wheels                 []
# 6845   Abrasive wheels                 []
# 7742   Abrasive wheels                 []
# 9137   Abrasive wheels                 []
# ...                ...                ...
# 21381            Yarns                 []
# 21529            Yarns                 []
# 21634            Yarns                 []
# 21707            Yarns                 []
# 21872            Yarns                 []
#
#                                              description  \
# 741    "Felt Wheels" are available in a variety of sh...
# 6649   The "Abrasive Grinding Wheel" manufactured by ...
# 6845   The "Diamond Cutting Disc Blade" manufactured ...
# 7742   The "Diamond Turbo Blade Cutting Disc Wheel" i...
# 9137   The "Abrasive Grinding Wheel" produced by Huaz...
# ...                                                  ...
# 21381  "Merino Wool Yarn" is a high-quality yarn craf...
# 21529  "DK Yarn" is a 3-DK (8ply) yarn manufactured b...
# 21634  "High Tea Yarns With Alix" is an annual event ...
# 21707  "Twist Yarn" from the Keld collection is desig...
# 21872  "Hand-Dyed Sock Yarn" is a premium, soft finge...
#
#                                          product_summary
# 741    Felt wheels available in various shapes and si...
# 6649   A 4 inch small abrasive grinding wheel manufac...
# 6845   A 300mm diamond cutting disc blade designed fo...
# 7742   A 125mm diamond turbo blade cutting disc wheel...
# 9137   A 4 inch small abrasive grinding wheel designe...
# ...                                                  ...
# 21381  Hand Spun Tasmanian Merino Wool Yarn in Rainbo...
# 21529  A 3-DK (8ply) yarn from Stylecraft, available ...
# 21634  The Summer High Tea Yarns With Alix is a uniqu...
# 21707  Twist yarns from the Keld collection, ideal fo...
# 21872  The Hand-Dyed Sock Yarn in Desert Sands is a p...
#
# [20589 rows x 4 columns]

# %%
cleaned_df = pd.concat([remove_duplicates_within_group(group) for _, group in tqdm(grouped, desc="Removing duplicates")])
print("Cleaned DataFrame with duplicates removed and empty descriptions/summaries eliminated:")
print(cleaned_df)
# Out:
# Removing duplicates: 100%|████████████████████████████████████████████████████████| 1492/1492 [00:10<00:00, 145.35it/s]
# Cleaned DataFrame with duplicates removed and empty descriptions/summaries eliminated:
#                 unspsc               root_domain  \
# 741    Abrasive wheels                 refima.eu
# 6649   Abrasive wheels          diamond-tool.net
# 6845   Abrasive wheels          diamond-tool.net
# 7742   Abrasive wheels          diamond-tool.net
# 9137   Abrasive wheels          diamond-tool.net
# ...                ...                       ...
# 21381            Yarns       sallyridgway.com.au
# 21529            Yarns  meanmotherscreations.com
# 21634            Yarns      yarnswithalix.com.au
# 21707            Yarns    edencottageyarns.co.uk
# 21872            Yarns     wattlebirdyarn.com.au
#
#                                                 page_url  \
# 741             https://www.refima.eu/technical-support/
# 6649   http://www.diamond-tool.net/product/cup-wheel.htm
# 6845   http://www.diamond-tool.net/product/diamond-bl...
# 7742   http://www.diamond-tool.net/product/best-diamo...
# 9137   http://www.diamond-tool.net/product/diamond-gr...
# ...                                                  ...
# 21381                       https://sallyridgway.com.au/
# 21529  https://meanmotherscreations.com/collections/3...
# 21634  https://www.yarnswithalix.com.au/products/summ...
# 21707      https://www.edencottageyarns.co.uk/pages/faqs
# 21872  https://wattlebirdyarn.com.au/products/hand-dy...
#
#                                            product_title  \
# 741                                          Felt Wheels
# 6649   Grinder Tool 4 Inch Small Abrasive Grinding Wheel
# 6845           Chop Saw Diamond Blade Cutting Disc 300mm
# 7742   125mm 5 Inch Diamond Turbo Blade Cutting Disc ...
# 9137   Grinder Tool 4 Inch Small Abrasive Grinding Wheel
# ...                                                  ...
# 21381    Hand Spun Tasmanian Merino Wool Yarn in Rainbow
# 21529                         Stylecraft Special DK Yarn
# 21634                    Summer High Tea Yarns With Alix
# 21707                                         Keld Twist
# 21872                  Hand-Dyed Sock Yarn: Desert Sands
#
#                                          product_summary  \
# 741    Felt wheels available in various shapes and si...
# 6649   A 4 inch small abrasive grinding wheel manufac...
# 6845   A 300mm diamond cutting disc blade designed fo...
# 7742   A 125mm diamond turbo blade cutting disc wheel...
# 9137   A 4 inch small abrasive grinding wheel designe...
# ...                                                  ...
# 21381  Hand Spun Tasmanian Merino Wool Yarn in Rainbo...
# 21529  A 3-DK (8ply) yarn from Stylecraft, available ...
# 21634  The Summer High Tea Yarns With Alix is a uniqu...
# 21707  Twist yarns from the Keld collection, ideal fo...
# 21872  The Hand-Dyed Sock Yarn in Desert Sands is a p...
#
#                                  product_name product_identifier  \
# 741                               Felt Wheels                 []
# 6649                  Abrasive Grinding Wheel                 []
# 6845               Diamond Cutting Disc Blade                 []
# 7742   Diamond Turbo Blade Cutting Disc Wheel                 []
# 9137                  Abrasive Grinding Wheel                 []
# ...                                       ...                ...
# 21381                        Merino Wool Yarn                 []
# 21529                                 DK Yarn                 []
# 21634                High Tea Yarns With Alix                 []
# 21707                              Twist Yarn                 []
# 21872                     Hand-Dyed Sock Yarn                 []
#
#                        brand            intended_industries  \
# 741                     None                [Manufacturing]
# 6649   Huazuan Diamond Tools                [Manufacturing]
# 6845                 HUAZUAN                 [Construction]
# 7742                    None  [Construction, Manufacturing]
# 9137   Huazuan Diamond Tools                [Manufacturing]
# ...                      ...                            ...
# 21381                   None             [Crafts, Textiles]
# 21529             Stylecraft                             []
# 21634                   None     [Crafts, Event Management]
# 21707                   None             [Crafts, Textiles]
# 21872                   None             [Crafts, Textiles]
#
#                                            applicability  ...  \
# 741                           [Various Shapes And Sizes]  ...
# 6649                                          [Grinding]  ...
# 6845                                  [stone processing]  ...
# 7742   [Cutting Through Stone, Cutting Through Concre...  ...
# 9137                                          [Grinding]  ...
# ...                                                  ...  ...
# 21381                                [Felting, Spinning]  ...
# 21529                                                 []  ...
# 21634                 [yarn making, high tea experience]  ...
# 21707           [creating textured and durable projects]  ...
# 21872          [knitting, crochet, creating accessories]  ...
#
#                                                     size  \
# 741                                                   []
# 6649   [{'dimension': 'Diameter', 'qualitative': Fals...
# 6845   [{'dimension': 'Diameter', 'qualitative': Fals...
# 7742   [{'dimension': 'Diameter', 'qualitative': Fals...
# 9137   [{'dimension': 'Diameter', 'qualitative': Fals...
# ...                                                  ...
# 21381                                                 []
# 21529                                                 []
# 21634                                                 []
# 21707                                                 []
# 21872  [{'dimension': 'Weight', 'qualitative': False,...
#
#                                                    color purity  \
# 741                                                   []     []
# 6649                                                  []     []
# 6845                                                  []     []
# 7742                                                  []     []
# 9137                                                  []     []
# ...                                                  ...    ...
# 21381                                                 []     []
# 21529                                                 []     []
# 21634                                                 []     []
# 21707                                                 []     []
# 21872  [{'original': 'Desert Sands', 'simple': 'Brown'}]     []
#
#       energy_efficiency pressure_rating power_rating  \
# 741                None              []           []
# 6649               None              []           []
# 6845               None              []           []
# 7742               None              []           []
# 9137               None              []           []
# ...                 ...             ...          ...
# 21381              None              []           []
# 21529              None              []           []
# 21634              None              []           []
# 21707              None              []           []
# 21872              None              []           []
#
#       quality_standards_and_certifications  \
# 741                                     []
# 6649                                    []
# 6845                                    []
# 7742                                    []
# 9137                                    []
# ...                                    ...
# 21381                                   []
# 21529                                   []
# 21634                                   []
# 21707                                   []
# 21872                                   []
#
#                                   miscellaneous_features  \
# 741                                                   []
# 6649                                                  []
# 6845                                   [stone processes]
# 7742         [Designed for wet and dry cut applications]
# 9137                                                  []
# ...                                                  ...
# 21381                                                 []
# 21529                                                 []
# 21634  [Annual event, Limited to one session, Sold ou...
# 21707                                                 []
# 21872  [Machine Washable on a Wool Cycle, Available f...
#
#                                              description  \
# 741    "Felt Wheels" are available in a variety of sh...
# 6649   The "Abrasive Grinding Wheel" manufactured by ...
# 6845   The "Diamond Cutting Disc Blade" manufactured ...
# 7742   The "Diamond Turbo Blade Cutting Disc Wheel" i...
# 9137   The "Abrasive Grinding Wheel" produced by Huaz...
# ...                                                  ...
# 21381  "Merino Wool Yarn" is a high-quality yarn craf...
# 21529  "DK Yarn" is a 3-DK (8ply) yarn manufactured b...
# 21634  "High Tea Yarns With Alix" is an annual event ...
# 21707  "Twist Yarn" from the Keld collection is desig...
# 21872  "Hand-Dyed Sock Yarn" is a premium, soft finge...
#
#                                            combined_text
# 741    "Felt Wheels" are available in a variety of sh...
# 6649   The "Abrasive Grinding Wheel" manufactured by ...
# 6845   The "Diamond Cutting Disc Blade" manufactured ...
# 7742   The "Diamond Turbo Blade Cutting Disc Wheel" i...
# 9137   The "Abrasive Grinding Wheel" produced by Huaz...
# ...                                                  ...
# 21381  "Merino Wool Yarn" is a high-quality yarn craf...
# 21529  "DK Yarn" is a 3-DK (8ply) yarn manufactured b...
# 21634  "High Tea Yarns With Alix" is an annual event ...
# 21707  "Twist Yarn" from the Keld collection is desig...
# 21872  "Hand-Dyed Sock Yarn" is a premium, soft finge...
#
# [20589 rows x 32 columns]

# %%
cleaned_df.to_csv(r'B:\Python\Veridion Project\Project 4\cleaned_products.csv', index=False)
